# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
# get matplot to show charts inline
# %matplotlib inline

# %% [markdown]
# chrome://settings/content/cookies
#
# NOTE: Make sure third party cookies are not blocked.

# %%
df = pd.read_csv('../../DATA/Employee-attrition.csv')

# %%
df.head(10)
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
# 5        1318  12/31/2011 0:00      1/3/1954        8/28/1989
# 6        1318  12/31/2012 0:00      1/3/1954        8/28/1989
# 7        1318  12/31/2013 0:00      1/3/1954        8/28/1989
# 8        1318  12/31/2014 0:00      1/3/1954        8/28/1989
# 9        1318  12/31/2015 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
# 5            1/1/1900   57                 22  Vancouver       Executive
# 6            1/1/1900   58                 23  Vancouver       Executive
# 7            1/1/1900   59                 24  Vancouver       Executive
# 8            1/1/1900   60                 25  Vancouver       Executive
# 9            1/1/1900   61                 26  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# 1       CEO          35            M        Male  Not Applicable
# 2       CEO          35            M        Male  Not Applicable
# 3       CEO          35            M        Male  Not Applicable
# 4       CEO          35            M        Male  Not Applicable
# 5       CEO          35            M        Male  Not Applicable
# 6       CEO          35            M        Male  Not Applicable
# 7       CEO          35            M        Male  Not Applicable
# 8       CEO          35            M        Male  Not Applicable
# 9       CEO          35            M        Male  Not Applicable
#
#     termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# 0  Not Applicable         2006  ACTIVE    HEADOFFICE
# 1  Not Applicable         2007  ACTIVE    HEADOFFICE
# 2  Not Applicable         2008  ACTIVE    HEADOFFICE
# 3  Not Applicable         2009  ACTIVE    HEADOFFICE
# 4  Not Applicable         2010  ACTIVE    HEADOFFICE
# 5  Not Applicable         2011  ACTIVE    HEADOFFICE
# 6  Not Applicable         2012  ACTIVE    HEADOFFICE
# 7  Not Applicable         2013  ACTIVE    HEADOFFICE
# 8  Not Applicable         2014  ACTIVE    HEADOFFICE
# 9  Not Applicable         2015  ACTIVE    HEADOFFICE

# %%
df.tail()
# Out:
#        EmployeeID  recorddate_key birthdate_key orighiredate_key  \
# 49648        8258  12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264   8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279  12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296  12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321  12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 49648          12/30/2015   21                  2    Valemount
# 49649           8/30/2013   19                  0    Vancouver
# 49650          12/30/2015   21                  2   White Rock
# 49651          12/31/2013   19                  0      Kelowna
# 49652          12/30/2014   20                  1  Grand Forks
#
#         department_name     job_title  store_name gender_short gender_full  \
# 49648             Dairy  Dairy Person          34            M        Male
# 49649  Customer Service       Cashier          44            F      Female
# 49650  Customer Service       Cashier          39            F      Female
# 49651  Customer Service       Cashier          16            F      Female
# 49652  Customer Service       Cashier          13            F      Female
#
#       termreason_desc termtype_desc  STATUS_YEAR      STATUS BUSINESS_UNIT
# 49648          Layoff   Involuntary         2015  TERMINATED        STORES
# 49649      Resignaton     Voluntary         2013  TERMINATED        STORES
# 49650          Layoff   Involuntary         2015  TERMINATED        STORES
# 49651      Resignaton     Voluntary         2013  TERMINATED        STORES
# 49652          Layoff   Involuntary         2014  TERMINATED        STORES

# %% [markdown]
# # Accessing the main DataFrame components

# %%
columns = df.columns
index = df.index
data = df.values

# %%
columns
# Out:
# Index(['EmployeeID', 'recorddate_key', 'birthdate_key', 'orighiredate_key',
#        'terminationdate_key', 'age', 'length_of_service', 'city_name',
#        'department_name', 'job_title', 'store_name', 'gender_short',
#        'gender_full', 'termreason_desc', 'termtype_desc', 'STATUS_YEAR',
#        'STATUS', 'BUSINESS_UNIT'],
#       dtype='object')

# %%
index
# Out:
# RangeIndex(start=0, stop=49653, step=1)

# %%
data
# Out:
# array([[1318, '12/31/2006 0:00', '1/3/1954', ..., 2006, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2007 0:00', '1/3/1954', ..., 2007, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2008 0:00', '1/3/1954', ..., 2008, 'ACTIVE',
#         'HEADOFFICE'],
#        ...,
#        [8279, '12/1/2015 0:00', '7/18/1994', ..., 2015, 'TERMINATED',
#         'STORES'],
#        [8296, '12/1/2013 0:00', '9/2/1994', ..., 2013, 'TERMINATED',
#         'STORES'],
#        [8321, '12/1/2014 0:00', '11/28/1994', ..., 2014, 'TERMINATED',
#         'STORES']], dtype=object)

# %% [markdown]
# # 1. Understanding Data Types

# %% [markdown]
# #### 1.A Find the shape of the dataframe

# %%
# A:
df.shape
# Out:
# (49653, 18)

# %% [markdown]
# #### 1.B Find the data types of the dataframe

# %%
# A
df.dtypes
# Out:
# EmployeeID              int64
# recorddate_key         object
# birthdate_key          object
# orighiredate_key       object
# terminationdate_key    object
# age                     int64
# length_of_service       int64
# city_name              object
# department_name        object
# job_title              object
# store_name              int64
# gender_short           object
# gender_full            object
# termreason_desc        object
# termtype_desc          object
# STATUS_YEAR             int64
# STATUS                 object
# BUSINESS_UNIT          object
# dtype: object

# %% [markdown]
# #### 1.C Find the number of data types in the dataframe
#
#
#
# ```
# Expected Output:
# int64      5
# object    13
# dtype: int64
# ```

# %%
df.dtypes.value_counts()
# Out:
# object    13
# int64      5
# Name: count, dtype: int64

# %% [markdown]
# #### 1.D Use Info
#
# Use info and explore the difference.

# %%
# A:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49653 entries, 0 to 49652
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EmployeeID           49653 non-null  int64
#  1   recorddate_key       49653 non-null  object
#  2   birthdate_key        49653 non-null  object
#  3   orighiredate_key     49653 non-null  object
#  4   terminationdate_key  49653 non-null  object
#  5   age                  49653 non-null  int64
#  6   length_of_service    49653 non-null  int64
#  7   city_name            49653 non-null  object
#  8   department_name      49653 non-null  object
#  9   job_title            49653 non-null  object
#  10  store_name           49653 non-null  int64
#  11  gender_short         49653 non-null  object
#  12  gender_full          49653 non-null  object
#  13  termreason_desc      49653 non-null  object
#  14  termtype_desc        49653 non-null  object
#  15  STATUS_YEAR          49653 non-null  int64
#  16  STATUS               49653 non-null  object
#  17  BUSINESS_UNIT        49653 non-null  object
# dtypes: int64(5), object(13)
# memory usage: 6.8+ MB

# %% [markdown]
# # 2. Selecting Column in Data Frame

# %% [markdown]
# #### 2.A Check Values of the `job_title` column

# %%
# A:
df['job_title']
# Out:
# 0                 CEO
# 1                 CEO
# 2                 CEO
# 3                 CEO
# 4                 CEO
#              ...
# 49648    Dairy Person
# 49649         Cashier
# 49650         Cashier
# 49651         Cashier
# 49652         Cashier
# Name: job_title, Length: 49653, dtype: object

# %% [markdown]
# #### 2.B Find how many rows are in each job title
#
#
#
# ```
# # Expected Output
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# .
# .
# .
# ```

# %%
# A:
df['job_title'].value_counts()
# Out:
# job_title
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# Baker                              8096
# Cashier                            6816
# Shelf Stocker                      5622
# Customer Service Manager            306
# Processed Foods Manager             289
# Bakery Manager                      285
# Meats Manager                       285
# Produce Manager                     278
# Store Manager                       271
# Recruiter                            62
# HRIS Analyst                         55
# Accounting Clerk                     50
# Benefits Admin                       35
# Labor Relations Analyst              30
# Accounts Receiveable Clerk           30
# Trainer                              26
# Accounts Payable Clerk               25
# Auditor                              20
# Systems Analyst                      20
# Investment Analyst                   20
# Compensation Analyst                 20
# Corporate Lawyer                     17
# CEO                                  10
# Exec Assistant, VP Stores            10
# Legal Counsel                        10
# VP Stores                            10
# VP Human Resources                   10
# VP Finance                           10
# Director, Recruitment                10
# Exec Assistant, Finance              10
# Exec Assistant, Human Resources      10
# CHief Information Officer            10
# Exec Assistant, Legal Counsel        10
# Director, Accounts Payable            9
# Director, Accounts Receivable         9
# Director, Employee Records            9
# Director, HR Technology               9
# Dairy Manager                         9
# Director, Accounting                  9
# Director, Investments                 4
# Director, Labor Relations             4
# Director, Compensation                4
# Director, Audit                       4
# Director, Training                    4
# Name: count, dtype: int64

# %% [markdown]
# #### 2.C [BONUS] Write a function to count the number of rows
#
#
# ```
# def row_count(column_name):
#     number_of_rows = 0
#     return number_of_rows
# ```

# %%
def row_count(column_name):
    no_of_rows = df.loc[:, column_name].count()
    return no_of_rows

# %%
row_count('age')
# Out:
# 49653

# %% [markdown]
# #### 2.D Describe `age`
#
# Find the count, mean, std, min, max of the column 'age'

# %%
# A:

# %%
df['age'].describe()
# Out:
# count    49653.000000
# mean        42.077035
# std         12.427257
# min         19.000000
# 25%         31.000000
# 50%         42.000000
# 75%         53.000000
# max         65.000000
# Name: age, dtype: float64

# %%
print(f"'Age' mean: {np.mean(df['age'])}")
print(f"'Age' min: {np.min(df['age'].astype('float'))}")
print(f"'Age' max: {np.max(df['age'].astype('float'))}")
# Out:
# 'Age' mean: 42.077034620264634
# 'Age' min: 19.0
# 'Age' max: 65.0

# %% [markdown]
# ##### 2.E [BONUS] Describe all numeric columns of the dataframe
#
# Find the count, mean, std, min, max of all columns of the dataframe

# %%
# A:
df.describe().T
# Out:
#                      count         mean          std     min     25%     50%  \
# EmployeeID         49653.0  4859.495740  1826.571142  1318.0  3360.0  5031.0
# age                49653.0    42.077035    12.427257    19.0    31.0    42.0
# length_of_service  49653.0    10.434596     6.325286     0.0     5.0    10.0
# store_name         49653.0    27.297605    13.514134     1.0    16.0    28.0
# STATUS_YEAR        49653.0  2010.612612     2.845577  2006.0  2008.0  2011.0
#
#                       75%     max
# EmployeeID         6335.0  8336.0
# age                  53.0    65.0
# length_of_service    15.0    26.0
# store_name           42.0    46.0
# STATUS_YEAR        2013.0  2015.0

# %% [markdown]
# # 3. Make the index meaningful by making `EmployeeID` the index

# %%
# A:
df.set_index('EmployeeID', inplace=True)

# %%
df.reset_index()
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0            8325  12/31/2013 0:00     12/7/1994       11/29/2013
# 1            8253  12/31/2013 0:00     5/15/1994        8/12/2013
# 2            8252  12/31/2013 0:00     5/10/1994         8/9/2013
# 3            8251  12/31/2013 0:00      5/7/1994         8/7/2013
# 4            8250  12/31/2013 0:00     4/26/1994         8/2/2013
# ...           ...              ...           ...              ...
# 49648        3262    8/1/2008 0:00     8/23/1943        2/28/1995
# 49649        3248    8/1/2008 0:00     8/14/1943        2/19/1995
# 49650        4948    7/1/2013 0:00      7/9/1948        1/14/2000
# 49651        3356   11/1/2008 0:00    11/18/1943        5/26/1995
# 49652        4138    2/1/2011 0:00     2/12/1946        8/20/1997
#
#       terminationdate_key  age  length_of_service        city_name  \
# 0                1/1/1900   19                  0        Cranbrook
# 1                1/1/1900   19                  0  North Vancouver
# 2                1/1/1900   19                  0         Victoria
# 3                1/1/1900   19                  0        Vancouver
# 4                1/1/1900   19                  0          Burnaby
# ...                   ...  ...                ...              ...
# 49648           8/23/2008   65                 13          Nanaimo
# 49649           8/14/2008   65                 13        Vancouver
# 49650            7/9/2013   65                 13          Burnaby
# 49651          11/18/2008   65                 13          Nanaimo
# 49652           2/12/2011   65                 13           Surrey
#
#         department_name      job_title  store_name gender_short gender_full  \
# 0      Customer Service        Cashier           8            M        Male
# 1      Customer Service        Cashier          22            F      Female
# 2      Customer Service        Cashier          46            F      Female
# 3      Customer Service        Cashier          44            F      Female
# 4                 Dairy   Dairy Person           5            F      Female
# ...                 ...            ...         ...          ...         ...
# 49648             Meats    Meat Cutter          18            F      Female
# 49649             Dairy   Dairy Person          35            F      Female
# 49650           Produce  Produce Clerk           5            F      Female
# 49651             Meats    Meat Cutter          18            F      Female
# 49652           Produce  Produce Clerk          31            F      Female
#
#       termreason_desc   termtype_desc  STATUS_YEAR      STATUS BUSINESS_UNIT
# 0      Not Applicable  Not Applicable         2013      ACTIVE        STORES
# 1      Not Applicable  Not Applicable         2013      ACTIVE        STORES
# 2      Not Applicable  Not Applicable         2013      ACTIVE        STORES
# 3      Not Applicable  Not Applicable         2013      ACTIVE        STORES
# 4      Not Applicable  Not Applicable         2013      ACTIVE        STORES
# ...               ...             ...          ...         ...           ...
# 49648      Retirement       Voluntary         2008  TERMINATED        STORES
# 49649      Retirement       Voluntary         2008  TERMINATED        STORES
# 49650      Retirement       Voluntary         2013  TERMINATED        STORES
# 49651      Retirement       Voluntary         2008  TERMINATED        STORES
# 49652      Retirement       Voluntary         2011  TERMINATED        STORES
#
# [49653 rows x 18 columns]

# %%
df
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 1318        12/31/2006 0:00      1/3/1954        8/28/1989
# 1318        12/31/2007 0:00      1/3/1954        8/28/1989
# 1318        12/31/2008 0:00      1/3/1954        8/28/1989
# 1318        12/31/2009 0:00      1/3/1954        8/28/1989
# 1318        12/31/2010 0:00      1/3/1954        8/28/1989
# ...                     ...           ...              ...
# 8258         12/1/2015 0:00     5/28/1994        8/19/2013
# 8264          8/1/2013 0:00     6/13/1994        8/27/2013
# 8279         12/1/2015 0:00     7/18/1994        9/15/2013
# 8296         12/1/2013 0:00      9/2/1994        10/9/2013
# 8321         12/1/2014 0:00    11/28/1994       11/24/2013
#
#            terminationdate_key  age  length_of_service    city_name  \
# EmployeeID
# 1318                  1/1/1900   52                 17    Vancouver
# 1318                  1/1/1900   53                 18    Vancouver
# 1318                  1/1/1900   54                 19    Vancouver
# 1318                  1/1/1900   55                 20    Vancouver
# 1318                  1/1/1900   56                 21    Vancouver
# ...                        ...  ...                ...          ...
# 8258                12/30/2015   21                  2    Valemount
# 8264                 8/30/2013   19                  0    Vancouver
# 8279                12/30/2015   21                  2   White Rock
# 8296                12/31/2013   19                  0      Kelowna
# 8321                12/30/2014   20                  1  Grand Forks
#
#              department_name     job_title  store_name gender_short  \
# EmployeeID
# 1318               Executive           CEO          35            M
# 1318               Executive           CEO          35            M
# 1318               Executive           CEO          35            M
# 1318               Executive           CEO          35            M
# 1318               Executive           CEO          35            M
# ...                      ...           ...         ...          ...
# 8258                   Dairy  Dairy Person          34            M
# 8264        Customer Service       Cashier          44            F
# 8279        Customer Service       Cashier          39            F
# 8296        Customer Service       Cashier          16            F
# 8321        Customer Service       Cashier          13            F
#
#            gender_full termreason_desc   termtype_desc  STATUS_YEAR  \
# EmployeeID
# 1318              Male  Not Applicable  Not Applicable         2006
# 1318              Male  Not Applicable  Not Applicable         2007
# 1318              Male  Not Applicable  Not Applicable         2008
# 1318              Male  Not Applicable  Not Applicable         2009
# 1318              Male  Not Applicable  Not Applicable         2010
# ...                ...             ...             ...          ...
# 8258              Male          Layoff     Involuntary         2015
# 8264            Female      Resignaton       Voluntary         2013
# 8279            Female          Layoff     Involuntary         2015
# 8296            Female      Resignaton       Voluntary         2013
# 8321            Female          Layoff     Involuntary         2014
#
#                 STATUS BUSINESS_UNIT
# EmployeeID
# 1318            ACTIVE    HEADOFFICE
# 1318            ACTIVE    HEADOFFICE
# 1318            ACTIVE    HEADOFFICE
# 1318            ACTIVE    HEADOFFICE
# 1318            ACTIVE    HEADOFFICE
# ...                ...           ...
# 8258        TERMINATED        STORES
# 8264        TERMINATED        STORES
# 8279        TERMINATED        STORES
# 8296        TERMINATED        STORES
# 8321        TERMINATED        STORES
#
# [49653 rows x 17 columns]

# %% [markdown]
# #### 3.A Find a specific row using the index

# %%
# A:

# %%
df.loc[8258]
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 8258        12/31/2013 0:00     5/28/1994        8/19/2013
# 8258        12/31/2014 0:00     5/28/1994        8/19/2013
# 8258         12/1/2015 0:00     5/28/1994        8/19/2013
#
#            terminationdate_key  age  length_of_service  city_name  \
# EmployeeID
# 8258                12/30/2015   19                  0  Valemount
# 8258                12/30/2015   20                  1  Valemount
# 8258                12/30/2015   21                  2  Valemount
#
#            department_name     job_title  store_name gender_short gender_full  \
# EmployeeID
# 8258                 Dairy  Dairy Person          34            M        Male
# 8258                 Dairy  Dairy Person          34            M        Male
# 8258                 Dairy  Dairy Person          34            M        Male
#
#            termreason_desc   termtype_desc  STATUS_YEAR      STATUS  \
# EmployeeID
# 8258        Not Applicable  Not Applicable         2013      ACTIVE
# 8258        Not Applicable  Not Applicable         2014      ACTIVE
# 8258                Layoff     Involuntary         2015  TERMINATED
#
#            BUSINESS_UNIT
# EmployeeID
# 8258              STORES
# 8258              STORES
# 8258              STORES

# %% [markdown]
# #### 3.B Sort the dataframe using the index

# %%
# A:
df.sort_index(axis=0, ascending=True)
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 1318        12/31/2006 0:00      1/3/1954        8/28/1989
# 1318        12/31/2007 0:00      1/3/1954        8/28/1989
# 1318        12/31/2008 0:00      1/3/1954        8/28/1989
# 1318        12/31/2009 0:00      1/3/1954        8/28/1989
# 1318        12/31/2010 0:00      1/3/1954        8/28/1989
# ...                     ...           ...              ...
# 8335        12/31/2013 0:00    12/28/1994       12/10/2013
# 8335        12/31/2015 0:00    12/28/1994       12/10/2013
# 8336        12/31/2015 0:00    12/31/1994       12/11/2013
# 8336        12/31/2013 0:00    12/31/1994       12/11/2013
# 8336        12/31/2014 0:00    12/31/1994       12/11/2013
#
#            terminationdate_key  age  length_of_service  city_name  \
# EmployeeID
# 1318                  1/1/1900   52                 17  Vancouver
# 1318                  1/1/1900   53                 18  Vancouver
# 1318                  1/1/1900   54                 19  Vancouver
# 1318                  1/1/1900   55                 20  Vancouver
# 1318                  1/1/1900   56                 21  Vancouver
# ...                        ...  ...                ...        ...
# 8335                  1/1/1900   19                  0  Vancouver
# 8335                  1/1/1900   21                  2  Vancouver
# 8336                  1/1/1900   21                  2  Vancouver
# 8336                  1/1/1900   19                  0  Vancouver
# 8336                  1/1/1900   20                  1  Vancouver
#
#            department_name     job_title  store_name gender_short gender_full  \
# EmployeeID
# 1318             Executive           CEO          35            M        Male
# 1318             Executive           CEO          35            M        Male
# 1318             Executive           CEO          35            M        Male
# 1318             Executive           CEO          35            M        Male
# 1318             Executive           CEO          35            M        Male
# ...                    ...           ...         ...          ...         ...
# 8335                 Dairy  Dairy Person          35            F      Female
# 8335                 Dairy  Dairy Person          35            F      Female
# 8336                 Dairy  Dairy Person          35            M        Male
# 8336                 Dairy  Dairy Person          35            M        Male
# 8336                 Dairy  Dairy Person          35            M        Male
#
#            termreason_desc   termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# EmployeeID
# 1318        Not Applicable  Not Applicable         2006  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2007  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2008  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2009  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2010  ACTIVE    HEADOFFICE
# ...                    ...             ...          ...     ...           ...
# 8335        Not Applicable  Not Applicable         2013  ACTIVE        STORES
# 8335        Not Applicable  Not Applicable         2015  ACTIVE        STORES
# 8336        Not Applicable  Not Applicable         2015  ACTIVE        STORES
# 8336        Not Applicable  Not Applicable         2013  ACTIVE        STORES
# 8336        Not Applicable  Not Applicable         2014  ACTIVE        STORES
#
# [49653 rows x 17 columns]

# %% [markdown]
# #### 3.C [BONUS] Sort the dataframe using `age`

# %%
# A:
df.sort_values(by='age', ascending=True, inplace=True)
df
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 8325        12/31/2013 0:00     12/7/1994       11/29/2013
# 8253        12/31/2013 0:00     5/15/1994        8/12/2013
# 8252        12/31/2013 0:00     5/10/1994         8/9/2013
# 8251        12/31/2013 0:00      5/7/1994         8/7/2013
# 8250        12/31/2013 0:00     4/26/1994         8/2/2013
# ...                     ...           ...              ...
# 3262          8/1/2008 0:00     8/23/1943        2/28/1995
# 3248          8/1/2008 0:00     8/14/1943        2/19/1995
# 4948          7/1/2013 0:00      7/9/1948        1/14/2000
# 3356         11/1/2008 0:00    11/18/1943        5/26/1995
# 4138          2/1/2011 0:00     2/12/1946        8/20/1997
#
#            terminationdate_key  age  length_of_service        city_name  \
# EmployeeID
# 8325                  1/1/1900   19                  0        Cranbrook
# 8253                  1/1/1900   19                  0  North Vancouver
# 8252                  1/1/1900   19                  0         Victoria
# 8251                  1/1/1900   19                  0        Vancouver
# 8250                  1/1/1900   19                  0          Burnaby
# ...                        ...  ...                ...              ...
# 3262                 8/23/2008   65                 13          Nanaimo
# 3248                 8/14/2008   65                 13        Vancouver
# 4948                  7/9/2013   65                 13          Burnaby
# 3356                11/18/2008   65                 13          Nanaimo
# 4138                 2/12/2011   65                 13           Surrey
#
#              department_name      job_title  store_name gender_short  \
# EmployeeID
# 8325        Customer Service        Cashier           8            M
# 8253        Customer Service        Cashier          22            F
# 8252        Customer Service        Cashier          46            F
# 8251        Customer Service        Cashier          44            F
# 8250                   Dairy   Dairy Person           5            F
# ...                      ...            ...         ...          ...
# 3262                   Meats    Meat Cutter          18            F
# 3248                   Dairy   Dairy Person          35            F
# 4948                 Produce  Produce Clerk           5            F
# 3356                   Meats    Meat Cutter          18            F
# 4138                 Produce  Produce Clerk          31            F
#
#            gender_full termreason_desc   termtype_desc  STATUS_YEAR  \
# EmployeeID
# 8325              Male  Not Applicable  Not Applicable         2013
# 8253            Female  Not Applicable  Not Applicable         2013
# 8252            Female  Not Applicable  Not Applicable         2013
# 8251            Female  Not Applicable  Not Applicable         2013
# 8250            Female  Not Applicable  Not Applicable         2013
# ...                ...             ...             ...          ...
# 3262            Female      Retirement       Voluntary         2008
# 3248            Female      Retirement       Voluntary         2008
# 4948            Female      Retirement       Voluntary         2013
# 3356            Female      Retirement       Voluntary         2008
# 4138            Female      Retirement       Voluntary         2011
#
#                 STATUS BUSINESS_UNIT
# EmployeeID
# 8325            ACTIVE        STORES
# 8253            ACTIVE        STORES
# 8252            ACTIVE        STORES
# 8251            ACTIVE        STORES
# 8250            ACTIVE        STORES
# ...                ...           ...
# 3262        TERMINATED        STORES
# 3248        TERMINATED        STORES
# 4948        TERMINATED        STORES
# 3356        TERMINATED        STORES
# 4138        TERMINATED        STORES
#
# [49653 rows x 17 columns]

# %% [markdown]
# #### 3.D [BONUS] Using `sample` select any row

# %%
# A:
df.sample(20)
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
#
# 8183            Female      Resignaton       Voluntary         2014
# 3956            Female  Not Applicable  Not Applicable         2011
# 3588            Female  Not Applicable  Not Applicable         2006
# 2326              Male  Not Applicable  Not Applicable         2013
# 7678              Male  Not Applicable  Not Applicable         2015
# 5861              Male  Not Applicable  Not Applicable         2013
# 7162              Male  Not Applicable  Not Applicable         2014
# 2752            Female  Not Applicable  Not Applicable         2007
# 6087              Male  Not Applicable  Not Applicable         2007
# 3952            Female  Not Applicable  Not Applicable         2015
#
#                 STATUS BUSINESS_UNIT
# EmployeeID
# 3178            ACTIVE        STORES
# 1929            ACTIVE        STORES
# 2622            ACTIVE        STORES
# 1840            ACTIVE        STORES
# 4451            ACTIVE        STORES
# 2604            ACTIVE        STORES
# 7118            ACTIVE        STORES
# 3364            ACTIVE        STORES
# 5669            ACTIVE        STORES
# 5717            ACTIVE        STORES
# 8183        TERMINATED        STORES
# 3956            ACTIVE        STORES
# 3588            ACTIVE        STORES
# 2326            ACTIVE        STORES
# 7678            ACTIVE        STORES
# 5861            ACTIVE        STORES
# 7162            ACTIVE        STORES
# 2752            ACTIVE        STORES
# 6087            ACTIVE        STORES
# 3952            ACTIVE        STORES

# %% [markdown]
# # 4. Query Data Frame
#
# #### 4.A Find rows Where `job_title` is CEO

# %%
# A:
df.loc[df['job_title'] == 'CEO']
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 1318        12/31/2006 0:00      1/3/1954        8/28/1989
# 1318        12/31/2007 0:00      1/3/1954        8/28/1989
# 1318        12/31/2008 0:00      1/3/1954        8/28/1989
# 1318        12/31/2009 0:00      1/3/1954        8/28/1989
# 1318        12/31/2010 0:00      1/3/1954        8/28/1989
# 1318        12/31/2011 0:00      1/3/1954        8/28/1989
# 1318        12/31/2012 0:00      1/3/1954        8/28/1989
# 1318        12/31/2013 0:00      1/3/1954        8/28/1989
# 1318        12/31/2014 0:00      1/3/1954        8/28/1989
# 1318        12/31/2015 0:00      1/3/1954        8/28/1989
#
#            terminationdate_key  age  length_of_service  city_name  \
# EmployeeID
# 1318                  1/1/1900   52                 17  Vancouver
# 1318                  1/1/1900   53                 18  Vancouver
# 1318                  1/1/1900   54                 19  Vancouver
# 1318                  1/1/1900   55                 20  Vancouver
# 1318                  1/1/1900   56                 21  Vancouver
# 1318                  1/1/1900   57                 22  Vancouver
# 1318                  1/1/1900   58                 23  Vancouver
# 1318                  1/1/1900   59                 24  Vancouver
# 1318                  1/1/1900   60                 25  Vancouver
# 1318                  1/1/1900   61                 26  Vancouver
#
#            department_name job_title  store_name gender_short gender_full  \
# EmployeeID
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
#
#            termreason_desc   termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# EmployeeID
# 1318        Not Applicable  Not Applicable         2006  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2007  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2008  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2009  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2010  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2011  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2012  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2013  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2014  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2015  ACTIVE    HEADOFFICE

# %% [markdown]
# #### 4.B Group by `age` and find how many there are of each age

# %%
# A:
df.groupby(by='age', as_index=True)['age'].count().reset_index(name='count')
# Out:
#     age  count
# 0    19    158
# 1    20    408
# 2    21    703
# 3    22    815
# 4    23    960
# 5    24   1111
# 6    25   1197
# 7    26   1210
# 8    27   1235
# 9    28   1225
# 10   29   1227
# 11   30   1212
# 12   31   1146
# 13   32   1153
# 14   33   1164
# 15   34   1188
# 16   35   1189
# 17   36   1176
# 18   37   1149
# 19   38   1156
# 20   39   1142
# 21   40   1130
# 22   41   1135
# 23   42   1152
# 24   43   1150
# 25   44   1157
# 26   45   1141
# 27   46   1161
# 28   47   1173
# 29   48   1180
# 30   49   1196
# 31   50   1218
# 32   51   1207
# 33   52   1188
# 34   53   1188
# 35   54   1159
# 36   55   1168
# 37   56   1154
# 38   57   1130
# 39   58   1130
# 40   59   1128
# 41   60   1109
# 42   61    757
# 43   62    712
# 44   63    667
# 45   64    646
# 46   65    593

# %% [markdown]
# # 5. Visualisation
#
#
# #### 5.A Plot a histogram of `age`

# %%
# A:
import seaborn as sns

sns.set_style('darkgrid')
bins_no = 20
plt.hist(x=df['age'], bins=bins_no, color='blue', alpha=0.5)

plt.title('Histogram of Age')
# Out:
# Text(0.5, 1.0, 'Histogram of Age')

# %% [markdown]
# #### 5.B BoxPlot of `age`

# %%
# A:
sns.set_style('darkgrid')
plt.boxplot(x=df['age'])

plt.title('Boxplot of Age')
# Out:
# Text(0.5, 1.0, 'Boxplot of Age')

# %% [markdown]
# #### 5.C Create a scatterplot of `age` and `length_of_service`

# %%
# A:
sns.set_style('darkgrid')
plt.scatter(x=df['age'], y=df['length_of_service'], color='brown', alpha=0.5)

plt.title('Scatter Plot of Age & Length Of Service')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Age & Length Of Service')

# %% [markdown]
# #### 5.D Print a statistical summary of `age`

# %%
# A:
df['age'].describe()
# Out:
# count    49653.000000
# mean        42.077035
# std         12.427257
# min         19.000000
# 25%         31.000000
# 50%         42.000000
# 75%         53.000000
# max         65.000000
# Name: age, dtype: float64

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2023 Institute of Data
#
#
# ---
#
#
#
# ---
